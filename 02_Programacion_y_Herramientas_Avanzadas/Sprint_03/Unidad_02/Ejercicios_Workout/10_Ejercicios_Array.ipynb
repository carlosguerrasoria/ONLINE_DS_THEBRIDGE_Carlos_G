# %% [markdown]
# <center>
# <center/>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <center>
# <center/>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Ejercicios Numpy: Arrays

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre el tipo Array de numpy, completa los siguiente ejercicios.
#
# La solución a los mismos se publicarán en el repo del curso a lo largo del sprint.

# %% [markdown]
# ### Ejercicio 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Importa el módulo de `numpy` y obtén su versión.

# %% [markdown]
# ## Ejercicio 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Crea un array de una dimensión que vaya de 0 a 9. Llamalo `my_array`

# %% [markdown]
# ## Ejercicio 3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Crea un array 3x3, que sea todo a True

# %% [markdown]
# ## Ejercicio 4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Extrae todos los impares de `my_array`

# %% [markdown]
# ## Ejercicio 5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# En un nuevo array, sustituye todos los impares de `my_array` por -1

# %% [markdown]
# ## Ejercicio 6
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Convierte `my_array` en un nuevo array de dos dimensiones mediante `reshape`.

# %% [markdown]
# ## Ejercicio 7
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Crea una matriz de 4x5, con una secuencia del 1 al 20
# 2. Invierte totalmente la matriz. Tanto las filas, como las columnas

# %% [markdown]
# ## Ejercicio 8
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Obtén el siguiente array, partiendo de la matriz del ejercicio 7
# ```Python
# array([[1, 2],
#        [6, 7]])
# ```

# %% [markdown]
# ## Ejercicio 9
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Obtén el siguiente array, partiendo de la matriz del ejercicio 7
# ```Python
# array([[ 1,  3,  5],
#        [11, 13, 15]])
# ```

# %% [markdown]
# ## Ejercicio 10
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Dado el siguiente array
#
# ```Python
# x =np.random.randint(10, 20, size = (5,2,6))
# ```
#
# 1. ¿Cuántos elementos tiene el array?
# 2. ¿Cuántas dimensiones?
# 3. ¿Cuántos elementos tiene cada dimensión?
# ```

# %% [markdown]
# ## Ejercicio 11
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Dado el siguiente array:
#
# ```Python
# x = np.array(["Loro", "Perro", "Gato", "Loro", "Perro"])
# ```
#
# Filtra el array para quedarte únicamente con los loros.
#
# Resuélvelo de dos maneras diferentes
